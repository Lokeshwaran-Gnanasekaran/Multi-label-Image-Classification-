# %% [markdown]
# # Assignment 2 Part 2: Developing Your Own Classifier

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/MyDrive/CS747_Assignment2")

# %%
import torch

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
# !bash /scratch/lnataray/tmp/DL/assignment2/CS747_Assignment2/download_data.sh
# Out:
# --2024-10-03 19:48:23--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  17.0MB/s    in 56s
#
# 2024-10-03 19:49:20 (7.82 MB/s) - ‘VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]
#
# --2024-10-03 19:50:05--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  8.43MB/s    in 63s
#
# 2024-10-03 19:51:08 (6.79 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]

# %%
pip install scikit-learn matplotlib opencv-python
# Out:
# Requirement already satisfied: scikit-learn in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (1.5.2)
# Requirement already satisfied: matplotlib in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (3.9.2)
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.19.5 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from scikit-learn) (2.1.1)
# Requirement already satisfied: scipy>=1.6.0 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 184.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.19.1-cp312-cp312-manylinux1_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: numpy in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torchvision) (2.1.1)
# Requirement already satisfied: torch==2.4.1 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torchvision) (2.4.1)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: filelock in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (4.12.2)
# Requirement already satisfied: sympy in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (1.13.3)
# Requirement already satisfied: networkx in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (2024.9.0)
# Requirement already satisfied: setuptools in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (75.1.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from torch==2.4.1->torchvision) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.1->torchvision) (12.6.77)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from jinja2->torch==2.4.1->torchvision) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/lnataray/miniconda3/envs/dlclass/lib/python3.12/site-packages (from sympy->torch==2.4.1->torchvision) (1.3.0)
# Downloading torchvision-0.19.1-cp312-cp312-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 56.5 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 80.0 MB/s eta 0:00:00
# Installing collected packages: pillow, torchvision
# Successfully installed pillow-10.4.0 torchvision-0.19.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Part 2: Design your own network
#
# In this notebook, your task is to create and train your own model for multi-label classification on VOC Pascal.
#
# ## What to do
# 1. You will make change on network architecture in ```classifier.py```.
# 2. You may also want to change other hyperparameters to assist your training to get a better performances. Hints will be given in the below instructions.
#
# ## What to submit
# Check the submission template for details what to submit.

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)

        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))

    return mAP, test_loss, aps

# %%
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency, scheduler):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
        scheduler.step()     

    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %% [markdown]
# # Developing Your Own Model

# %% [markdown]
# ### Goal
# To meet the benchmark for this assignment you will need to improve the network. Note you should have noticed pretrained Alenxt performs really well, but training Alexnet from scratch performs much worse. We hope you can design a better architecture over both the simple classifier and AlexNet to train from scratch.
#
# ### How to start
# You may take inspiration from other published architectures and architectures discussed in lecture. However, you are NOT allowed to use predefined models (e.g. models from torchvision) or use pretrained weights. Training must be done from scratch with your own custom model.
#
# #### Some hints
# There are a variety of different approaches you should try to improve performance from the simple classifier:
#
# * Network architecture changes
#     * Number of layers: try adding layers to make your network deeper
#     * Batch normalization: adding batch norm between layers will likely give you a significant performance increase
#     * Residual connections: as you increase the depth of your network, you will find that having residual connections like those in ResNet architectures will be helpful
# * Optimizer: Instead of plain SGD, you may want to add a learning rate schedule, add momentum, or use one of the other optimizers you have learned about like Adam. Check the `torch.optim` package for other optimizers
# * Data augmentation: You should use the `torchvision.transforms` module to try adding random resized crops and horizontal flips of the input data. Check `transforms.RandomResizedCrop` and `transforms.RandomHorizontalFlip` for this. Feel free to apply more [transforms](https://pytorch.org/docs/stable/torchvision/transforms.html) for data augmentation which can lead to better performance.
# * Epochs: Once you have found a generally good hyperparameter setting try training for more epochs
# * Loss function: You might want to add weighting to the `MultiLabelSoftMarginLoss` for classes that are less well represented or experiment with a different loss function
#
#
#
# #### Note
# We will soon be providing some initial expectations of mAP values as a function of epoch so you can get an early idea whether your implementation works without waiting a long time for training to converge.
#
# ### What to submit
# Submit your best model to Kaggle and save all plots for the writeup.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])
gaussian_normalize = transforms.Normalize(mean=[0.5, 0.5, 0.5],
                                          std=[0.5, 0.5, 0.5])

train_transform = transforms.Compose([
    transforms.Resize((300, 300)),  # Resize image first
    transforms.RandomHorizontalFlip(),  # Random flip
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # Augment brightness, contrast, etc.
    transforms.RandomRotation(10),  # Random rotation
    transforms.CenterCrop(300),
    transforms.ToTensor(),  # Convert PIL image to tensor
    transforms.RandomErasing(p=0.5),  # Erasing should happen after converting to tensor
    gaussian_normalize  # Apply normalization last
])

test_transform = transforms.Compose([
    transforms.Resize((300, 300)),
    transforms.CenterCrop(300),
    transforms.ToTensor(),
    transforms.Lambda(gaussian_normalize)  # Normalize as well
])

ds_train = VocDataset('VOCdevkit_2007/VOC2007','train',train_transform)
# ds_val = VocDataset('VOCdevkit_2007/VOC2007/','val',test_transform)
# ds_test = VocDataset('VOCdevkit_2007/VOC2007test/','test', test_transform)

# %%
num_epochs = 100
test_frequency = 5
batch_size = 128

train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size,
                                               shuffle=True,
                                               num_workers=1)

# val_loader = torch.utils.data.DataLoader(dataset=ds_val,
#                                                batch_size=batch_size,
#                                                shuffle=True,
#                                                num_workers=1)

# test_loader = torch.utils.data.DataLoader(dataset=ds_test,
#                                                batch_size=batch_size,
#                                                shuffle=False,
#                                                num_workers=1)

# %%
ds_val = VocDataset('VOCdevkit_2007/VOC2007/','val',test_transform)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size,
                                               shuffle=True,
                                               num_workers=1)

# %%
def gaussian_weights_init(m):
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        
        nn.init.normal_(m.weight, mean=0.0, std=0.02)  
        if m.bias is not None:
            nn.init.zeros_(m.bias)

# %%
# TODO: Run your own classifier here
classifier = Classifier().to(device)
# classifier.apply(gaussian_weights_init)
criterion = nn.BCEWithLogitsLoss()
# optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
optimizer = torch.optim.AdamW(classifier.parameters(), lr=1e-4, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency, scheduler)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.513567328453064
# -------  Class: aeroplane        AP:   0.0654  -------
# -------  Class: bicycle          AP:   0.0675  -------
# -------  Class: bird             AP:   0.0545  -------
# -------  Class: boat             AP:   0.0513  -------
# -------  Class: bottle           AP:   0.0350  -------
# -------  Class: bus              AP:   0.0598  -------
# -------  Class: car              AP:   0.1650  -------
# -------  Class: cat              AP:   0.0644  -------
# -------  Class: chair            AP:   0.1035  -------
# -------  Class: cow              AP:   0.0351  -------
# -------  Class: diningtable      AP:   0.0461  -------
# -------  Class: dog              AP:   0.0741  -------
# -------  Class: horse            AP:   0.0639  -------
# -------  Class: motorbike        AP:   0.0447  -------
# -------  Class: person           AP:   0.4418  -------
# -------  Class: pottedplant      AP:   0.0486  -------
# -------  Class: sheep            AP:   0.0223  -------
# -------  Class: sofa             AP:   0.0643  -------
# -------  Class: train            AP:   0.1260  -------
# -------  Class: tvmonitor        AP:   0.0555  -------
# mAP: 0.0844
# Avg loss: 0.32073294967412946
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08444423284093464
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.3111090660095215
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.26367878913879395
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.25300347805023193
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.24730800092220306
# -------  Class: aeroplane        AP:   0.3629  -------
# -------  Class: bicycle          AP:   0.0849  -------
# -------  Class: bird             AP:   0.1027  -------
# -------  Class: boat             AP:   0.2364  -------
# -------  Class: bottle           AP:   0.1022  -------
# -------  Class: bus              AP:   0.1046  -------
# -------  Class: car              AP:   0.2642  -------
# -------  Class: cat              AP:   0.1931  -------
# -------  Class: chair            AP:   0.2039  -------
# -------  Class: cow              AP:   0.0521  -------
# -------  Class: diningtable      AP:   0.1557  -------
# -------  Class: dog              AP:   0.1504  -------
# -------  Class: horse            AP:   0.0818  -------
# -------  Class: motorbike        AP:   0.1169  -------
# -------  Class: person           AP:   0.5034  -------
# -------  Class: pottedplant      AP:   0.0852  -------
# -------  Class: sheep            AP:   0.0319  -------
# -------  Class: sofa             AP:   0.1444  -------
# -------  Class: train            AP:   0.1540  -------
# -------  Class: tvmonitor        AP:   0.0657  -------
# mAP: 0.1598
# Avg loss: 0.22015455961227418
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.15982109799872862
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.24314026534557343
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.23901763558387756
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.23504972457885742
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.23079033195972443
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.22916264832019806
# -------  Class: aeroplane        AP:   0.4044  -------
# -------  Class: bicycle          AP:   0.1075  -------
# -------  Class: bird             AP:   0.1482  -------
# -------  Class: boat             AP:   0.2616  -------
# -------  Class: bottle           AP:   0.1422  -------
# -------  Class: bus              AP:   0.1171  -------
# -------  Class: car              AP:   0.4113  -------
# -------  Class: cat              AP:   0.1883  -------
# -------  Class: chair            AP:   0.2893  -------
# -------  Class: cow              AP:   0.0350  -------
# -------  Class: diningtable      AP:   0.2273  -------
# -------  Class: dog              AP:   0.1647  -------
# -------  Class: horse            AP:   0.1677  -------
# -------  Class: motorbike        AP:   0.1818  -------
# -------  Class: person           AP:   0.5717  -------
# -------  Class: pottedplant      AP:   0.1019  -------
# -------  Class: sheep            AP:   0.0689  -------
# -------  Class: sofa             AP:   0.1916  -------
# -------  Class: train            AP:   0.1931  -------
# -------  Class: tvmonitor        AP:   0.1054  -------
# mAP: 0.2040
# Avg loss: 0.21079194396734238
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.2039564553001329
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.22597841918468475
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.22112400829792023
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.2205616980791092
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.21784554421901703
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.2137521356344223
# -------  Class: aeroplane        AP:   0.4756  -------
# -------  Class: bicycle          AP:   0.2191  -------
# -------  Class: bird             AP:   0.1471  -------
# -------  Class: boat             AP:   0.3437  -------
# -------  Class: bottle           AP:   0.1460  -------
# -------  Class: bus              AP:   0.1614  -------
# -------  Class: car              AP:   0.4966  -------
# -------  Class: cat              AP:   0.2663  -------
# -------  Class: chair            AP:   0.3389  -------
# -------  Class: cow              AP:   0.0672  -------
# -------  Class: diningtable      AP:   0.2898  -------
# -------  Class: dog              AP:   0.1926  -------
# -------  Class: horse            AP:   0.2610  -------
# -------  Class: motorbike        AP:   0.3008  -------
# -------  Class: person           AP:   0.6288  -------
# -------  Class: pottedplant      AP:   0.1449  -------
# -------  Class: sheep            AP:   0.1230  -------
# -------  Class: sofa             AP:   0.2283  -------
# -------  Class: train            AP:   0.3591  -------
# -------  Class: tvmonitor        AP:   0.1790  -------
# mAP: 0.2685
# Avg loss: 0.196894334256649
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.2684637222123786
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.21265344321727753
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.20893028378486633
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.20603103935718536
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.20511917769908905
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.200531005859375
# -------  Class: aeroplane        AP:   0.5169  -------
# -------  Class: bicycle          AP:   0.2538  -------
# -------  Class: bird             AP:   0.1643  -------
# -------  Class: boat             AP:   0.3694  -------
# -------  Class: bottle           AP:   0.1504  -------
# -------  Class: bus              AP:   0.1996  -------
# -------  Class: car              AP:   0.5409  -------
# -------  Class: cat              AP:   0.2433  -------
# -------  Class: chair            AP:   0.3563  -------
# -------  Class: cow              AP:   0.0783  -------
# -------  Class: diningtable      AP:   0.3009  -------
# -------  Class: dog              AP:   0.2333  -------
# -------  Class: horse            AP:   0.3245  -------
# -------  Class: motorbike        AP:   0.2771  -------
# -------  Class: person           AP:   0.6766  -------
# -------  Class: pottedplant      AP:   0.1365  -------
# -------  Class: sheep            AP:   0.1242  -------
# -------  Class: sofa             AP:   0.2211  -------
# -------  Class: train            AP:   0.4281  -------
# -------  Class: tvmonitor        AP:   0.2057  -------
# mAP: 0.2901
# Avg loss: 0.2031462423503399
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.29006555534748074
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.19893012940883636
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.1963343620300293
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.19346921145915985
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.1911333203315735
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.18981057405471802
# -------  Class: aeroplane        AP:   0.5340  -------
# -------  Class: bicycle          AP:   0.2521  -------
# -------  Class: bird             AP:   0.1885  -------
# -------  Class: boat             AP:   0.4241  -------
# -------  Class: bottle           AP:   0.1634  -------
# -------  Class: bus              AP:   0.2632  -------
# -------  Class: car              AP:   0.5849  -------
# -------  Class: cat              AP:   0.3162  -------
# -------  Class: chair            AP:   0.3914  -------
# -------  Class: cow              AP:   0.1016  -------
# -------  Class: diningtable      AP:   0.2838  -------
# -------  Class: dog              AP:   0.2464  -------
# -------  Class: horse            AP:   0.3851  -------
# -------  Class: motorbike        AP:   0.4098  -------
# -------  Class: person           AP:   0.6988  -------
# -------  Class: pottedplant      AP:   0.1564  -------
# -------  Class: sheep            AP:   0.1425  -------
# -------  Class: sofa             AP:   0.2403  -------
# -------  Class: train            AP:   0.5048  -------
# -------  Class: tvmonitor        AP:   0.3013  -------
# mAP: 0.3294
# Avg loss: 0.1837727092206478
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.3294146615517853
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.1887984722852707
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.18511289358139038
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.18372444808483124
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.1843070238828659
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.17901869118213654
# -------  Class: aeroplane        AP:   0.5432  -------
# -------  Class: bicycle          AP:   0.3013  -------
# -------  Class: bird             AP:   0.2203  -------
# -------  Class: boat             AP:   0.4613  -------
# -------  Class: bottle           AP:   0.1528  -------
# -------  Class: bus              AP:   0.3342  -------
# -------  Class: car              AP:   0.5882  -------
# -------  Class: cat              AP:   0.3491  -------
# -------  Class: chair            AP:   0.4011  -------
# -------  Class: cow              AP:   0.1090  -------
# -------  Class: diningtable      AP:   0.2950  -------
# -------  Class: dog              AP:   0.2544  -------
# -------  Class: horse            AP:   0.4597  -------
# -------  Class: motorbike        AP:   0.4245  -------
# -------  Class: person           AP:   0.7112  -------
# -------  Class: pottedplant      AP:   0.1592  -------
# -------  Class: sheep            AP:   0.1318  -------
# -------  Class: sofa             AP:   0.2606  -------
# -------  Class: train            AP:   0.5297  -------
# -------  Class: tvmonitor        AP:   0.3365  -------
# mAP: 0.3511
# Avg loss: 0.18180361166596412
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.35114612194983463
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.17828495800495148
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.1777019500732422
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.1774718314409256
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.1764575093984604
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.17302261292934418
# -------  Class: aeroplane        AP:   0.6209  -------
# -------  Class: bicycle          AP:   0.3423  -------
# -------  Class: bird             AP:   0.2439  -------
# -------  Class: boat             AP:   0.4848  -------
# -------  Class: bottle           AP:   0.1397  -------
# -------  Class: bus              AP:   0.2912  -------
# -------  Class: car              AP:   0.6353  -------
# -------  Class: cat              AP:   0.3558  -------
# -------  Class: chair            AP:   0.4499  -------
# -------  Class: cow              AP:   0.1398  -------
# -------  Class: diningtable      AP:   0.3441  -------
# -------  Class: dog              AP:   0.2798  -------
# -------  Class: horse            AP:   0.4909  -------
# -------  Class: motorbike        AP:   0.4721  -------
# -------  Class: person           AP:   0.7444  -------
# -------  Class: pottedplant      AP:   0.1759  -------
# -------  Class: sheep            AP:   0.1320  -------
# -------  Class: sofa             AP:   0.2988  -------
# -------  Class: train            AP:   0.5867  -------
# -------  Class: tvmonitor        AP:   0.3342  -------
# mAP: 0.3781
# Avg loss: 0.17980564013123512
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 35 is 0.37812478236237845
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.17316487431526184
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.170545294880867
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.16785921156406403
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.16686104238033295
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.16526727378368378
# -------  Class: aeroplane        AP:   0.6260  -------
# -------  Class: bicycle          AP:   0.3677  -------
# -------  Class: bird             AP:   0.2643  -------
# -------  Class: boat             AP:   0.4861  -------
# -------  Class: bottle           AP:   0.1587  -------
# -------  Class: bus              AP:   0.3084  -------
# -------  Class: car              AP:   0.6394  -------
# -------  Class: cat              AP:   0.3578  -------
# -------  Class: chair            AP:   0.4332  -------
# -------  Class: cow              AP:   0.1585  -------
# -------  Class: diningtable      AP:   0.3551  -------
# -------  Class: dog              AP:   0.2827  -------
# -------  Class: horse            AP:   0.5180  -------
# -------  Class: motorbike        AP:   0.4999  -------
# -------  Class: person           AP:   0.7396  -------
# -------  Class: pottedplant      AP:   0.1700  -------
# -------  Class: sheep            AP:   0.1351  -------
# -------  Class: sofa             AP:   0.2769  -------
# -------  Class: train            AP:   0.6284  -------
# -------  Class: tvmonitor        AP:   0.3377  -------
# mAP: 0.3872
# Avg loss: 0.17702090591192246
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 40 is 0.38717013590547883
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.1649509221315384
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.164520725607872
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.16307063400745392
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.15921607613563538
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.15767835080623627
# -------  Class: aeroplane        AP:   0.6368  -------
# -------  Class: bicycle          AP:   0.3691  -------
# -------  Class: bird             AP:   0.3044  -------
# -------  Class: boat             AP:   0.5039  -------
# -------  Class: bottle           AP:   0.1824  -------
# -------  Class: bus              AP:   0.3143  -------
# -------  Class: car              AP:   0.6416  -------
# -------  Class: cat              AP:   0.3445  -------
# -------  Class: chair            AP:   0.4643  -------
# -------  Class: cow              AP:   0.1596  -------
# -------  Class: diningtable      AP:   0.3350  -------
# -------  Class: dog              AP:   0.3189  -------
# -------  Class: horse            AP:   0.4850  -------
# -------  Class: motorbike        AP:   0.4706  -------
# -------  Class: person           AP:   0.7491  -------
# -------  Class: pottedplant      AP:   0.1538  -------
# -------  Class: sheep            AP:   0.1103  -------
# -------  Class: sofa             AP:   0.3341  -------
# -------  Class: train            AP:   0.6582  -------
# -------  Class: tvmonitor        AP:   0.3985  -------
# mAP: 0.3967
# Avg loss: 0.17600816935300828
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 45 is 0.3967063056062257
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.1579250544309616
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.15811888873577118
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.15670637786388397
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.1545991152524948
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.15481702983379364
# -------  Class: aeroplane        AP:   0.6484  -------
# -------  Class: bicycle          AP:   0.3841  -------
# -------  Class: bird             AP:   0.3261  -------
# -------  Class: boat             AP:   0.4930  -------
# -------  Class: bottle           AP:   0.1807  -------
# -------  Class: bus              AP:   0.3289  -------
# -------  Class: car              AP:   0.6409  -------
# -------  Class: cat              AP:   0.3915  -------
# -------  Class: chair            AP:   0.4443  -------
# -------  Class: cow              AP:   0.1576  -------
# -------  Class: diningtable      AP:   0.3714  -------
# -------  Class: dog              AP:   0.3103  -------
# -------  Class: horse            AP:   0.5194  -------
# -------  Class: motorbike        AP:   0.5437  -------
# -------  Class: person           AP:   0.7563  -------
# -------  Class: pottedplant      AP:   0.1648  -------
# -------  Class: sheep            AP:   0.1107  -------
# -------  Class: sofa             AP:   0.3127  -------
# -------  Class: train            AP:   0.6714  -------
# -------  Class: tvmonitor        AP:   0.3570  -------
# mAP: 0.4057
# Avg loss: 0.1716835990548134
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.40566881280619294
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.15285316109657288
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.1521327793598175
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.14947913587093353
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.14897660911083221
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.14672358334064484
# -------  Class: aeroplane        AP:   0.6576  -------
# -------  Class: bicycle          AP:   0.4431  -------
# -------  Class: bird             AP:   0.2806  -------
# -------  Class: boat             AP:   0.5234  -------
# -------  Class: bottle           AP:   0.1646  -------
# -------  Class: bus              AP:   0.2970  -------
# -------  Class: car              AP:   0.6340  -------
# -------  Class: cat              AP:   0.3451  -------
# -------  Class: chair            AP:   0.4517  -------
# -------  Class: cow              AP:   0.1860  -------
# -------  Class: diningtable      AP:   0.3196  -------
# -------  Class: dog              AP:   0.2876  -------
# -------  Class: horse            AP:   0.5372  -------
# -------  Class: motorbike        AP:   0.5654  -------
# -------  Class: person           AP:   0.7353  -------
# -------  Class: pottedplant      AP:   0.1911  -------
# -------  Class: sheep            AP:   0.1382  -------
# -------  Class: sofa             AP:   0.3369  -------
# -------  Class: train            AP:   0.6541  -------
# -------  Class: tvmonitor        AP:   0.3914  -------
# mAP: 0.4070
# Avg loss: 0.17835719510912895
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 55 is 0.40699506626885124
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.14724169671535492
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.14715518057346344
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.14559319615364075
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.14461930096149445
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.14493198692798615
# -------  Class: aeroplane        AP:   0.6724  -------
# -------  Class: bicycle          AP:   0.4257  -------
# -------  Class: bird             AP:   0.3246  -------
# -------  Class: boat             AP:   0.5313  -------
# -------  Class: bottle           AP:   0.1711  -------
# -------  Class: bus              AP:   0.2996  -------
# -------  Class: car              AP:   0.6808  -------
# -------  Class: cat              AP:   0.3849  -------
# -------  Class: chair            AP:   0.4544  -------
# -------  Class: cow              AP:   0.1939  -------
# -------  Class: diningtable      AP:   0.3685  -------
# -------  Class: dog              AP:   0.3263  -------
# -------  Class: horse            AP:   0.5461  -------
# -------  Class: motorbike        AP:   0.5946  -------
# -------  Class: person           AP:   0.7618  -------
# -------  Class: pottedplant      AP:   0.2102  -------
# -------  Class: sheep            AP:   0.1505  -------
# -------  Class: sofa             AP:   0.3512  -------
# -------  Class: train            AP:   0.6811  -------
# -------  Class: tvmonitor        AP:   0.4076  -------
# mAP: 0.4268
# Avg loss: 0.16909845694899558
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 60 is 0.42682589107084334
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.1412799209356308
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.14092835783958435
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.14112626016139984
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.13872043788433075
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.13874311745166779
# -------  Class: aeroplane        AP:   0.6801  -------
# -------  Class: bicycle          AP:   0.4518  -------
# -------  Class: bird             AP:   0.3401  -------
# -------  Class: boat             AP:   0.5485  -------
# -------  Class: bottle           AP:   0.1656  -------
# -------  Class: bus              AP:   0.3294  -------
# -------  Class: car              AP:   0.6791  -------
# -------  Class: cat              AP:   0.3809  -------
# -------  Class: chair            AP:   0.4638  -------
# -------  Class: cow              AP:   0.2136  -------
# -------  Class: diningtable      AP:   0.3566  -------
# -------  Class: dog              AP:   0.3438  -------
# -------  Class: horse            AP:   0.5579  -------
# -------  Class: motorbike        AP:   0.6021  -------
# -------  Class: person           AP:   0.7592  -------
# -------  Class: pottedplant      AP:   0.1878  -------
# -------  Class: sheep            AP:   0.1561  -------
# -------  Class: sofa             AP:   0.3766  -------
# -------  Class: train            AP:   0.6756  -------
# -------  Class: tvmonitor        AP:   0.4251  -------
# mAP: 0.4347
# Avg loss: 0.16694003120064735
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 65 is 0.43467880457895164
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.14000077545642853
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.1378132402896881
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.1375492364168167
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.13681185245513916
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.13587859272956848
# -------  Class: aeroplane        AP:   0.6779  -------
# -------  Class: bicycle          AP:   0.4348  -------
# -------  Class: bird             AP:   0.3275  -------
# -------  Class: boat             AP:   0.5662  -------
# -------  Class: bottle           AP:   0.1885  -------
# -------  Class: bus              AP:   0.3272  -------
# -------  Class: car              AP:   0.6743  -------
# -------  Class: cat              AP:   0.3903  -------
# -------  Class: chair            AP:   0.4608  -------
# -------  Class: cow              AP:   0.1954  -------
# -------  Class: diningtable      AP:   0.3935  -------
# -------  Class: dog              AP:   0.3243  -------
# -------  Class: horse            AP:   0.5640  -------
# -------  Class: motorbike        AP:   0.6009  -------
# -------  Class: person           AP:   0.7647  -------
# -------  Class: pottedplant      AP:   0.1881  -------
# -------  Class: sheep            AP:   0.1491  -------
# -------  Class: sofa             AP:   0.3487  -------
# -------  Class: train            AP:   0.6710  -------
# -------  Class: tvmonitor        AP:   0.4169  -------
# mAP: 0.4332
# Avg loss: 0.16892691627144812
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 70 is 0.43319793027058334
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.1331205666065216
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.13425078988075256
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.1324814260005951
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.13320547342300415
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.13259828090667725
# -------  Class: aeroplane        AP:   0.6610  -------
# -------  Class: bicycle          AP:   0.4428  -------
# -------  Class: bird             AP:   0.3544  -------
# -------  Class: boat             AP:   0.5645  -------
# -------  Class: bottle           AP:   0.1853  -------
# -------  Class: bus              AP:   0.3507  -------
# -------  Class: car              AP:   0.6803  -------
# -------  Class: cat              AP:   0.3913  -------
# -------  Class: chair            AP:   0.4628  -------
# -------  Class: cow              AP:   0.2089  -------
# -------  Class: diningtable      AP:   0.3946  -------
# -------  Class: dog              AP:   0.3409  -------
# -------  Class: horse            AP:   0.5645  -------
# -------  Class: motorbike        AP:   0.5902  -------
# -------  Class: person           AP:   0.7659  -------
# -------  Class: pottedplant      AP:   0.1971  -------
# -------  Class: sheep            AP:   0.1509  -------
# -------  Class: sofa             AP:   0.3513  -------
# -------  Class: train            AP:   0.6806  -------
# -------  Class: tvmonitor        AP:   0.4255  -------
# mAP: 0.4382
# Avg loss: 0.16777067631483078
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 75 is 0.4381732398088311
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.13103888928890228
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.1311013251543045
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.1326713263988495
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.13098172843456268
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.1302233338356018
# -------  Class: aeroplane        AP:   0.6738  -------
# -------  Class: bicycle          AP:   0.4598  -------
# -------  Class: bird             AP:   0.3499  -------
# -------  Class: boat             AP:   0.5534  -------
# -------  Class: bottle           AP:   0.1888  -------
# -------  Class: bus              AP:   0.3780  -------
# -------  Class: car              AP:   0.6803  -------
# -------  Class: cat              AP:   0.3850  -------
# -------  Class: chair            AP:   0.4658  -------
# -------  Class: cow              AP:   0.2127  -------
# -------  Class: diningtable      AP:   0.3807  -------
# -------  Class: dog              AP:   0.3443  -------
# -------  Class: horse            AP:   0.5618  -------
# -------  Class: motorbike        AP:   0.6131  -------
# -------  Class: person           AP:   0.7610  -------
# -------  Class: pottedplant      AP:   0.1983  -------
# -------  Class: sheep            AP:   0.1469  -------
# -------  Class: sofa             AP:   0.3600  -------
# -------  Class: train            AP:   0.6785  -------
# -------  Class: tvmonitor        AP:   0.4379  -------
# mAP: 0.4415
# Avg loss: 0.16778693571686745
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 80 is 0.4415002007211536
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.13130788505077362
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.13057668507099152
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.12984822690486908
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.12824976444244385
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.12844610214233398
# -------  Class: aeroplane        AP:   0.6787  -------
# -------  Class: bicycle          AP:   0.4497  -------
# -------  Class: bird             AP:   0.3640  -------
# -------  Class: boat             AP:   0.5546  -------
# -------  Class: bottle           AP:   0.1945  -------
# -------  Class: bus              AP:   0.3387  -------
# -------  Class: car              AP:   0.6892  -------
# -------  Class: cat              AP:   0.3960  -------
# -------  Class: chair            AP:   0.4657  -------
# -------  Class: cow              AP:   0.2148  -------
# -------  Class: diningtable      AP:   0.3903  -------
# -------  Class: dog              AP:   0.3515  -------
# -------  Class: horse            AP:   0.5635  -------
# -------  Class: motorbike        AP:   0.6164  -------
# -------  Class: person           AP:   0.7705  -------
# -------  Class: pottedplant      AP:   0.2080  -------
# -------  Class: sheep            AP:   0.1479  -------
# -------  Class: sofa             AP:   0.3654  -------
# -------  Class: train            AP:   0.6799  -------
# -------  Class: tvmonitor        AP:   0.4326  -------
# mAP: 0.4436
# Avg loss: 0.16704690009355544
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 85 is 0.4435925338083808
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.1304328888654709
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.1274537295103073
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.12831798195838928
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.12830595672130585
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.12836886942386627
# -------  Class: aeroplane        AP:   0.6734  -------
# -------  Class: bicycle          AP:   0.4551  -------
# -------  Class: bird             AP:   0.3629  -------
# -------  Class: boat             AP:   0.5495  -------
# -------  Class: bottle           AP:   0.1933  -------
# -------  Class: bus              AP:   0.3351  -------
# -------  Class: car              AP:   0.6828  -------
# -------  Class: cat              AP:   0.4000  -------
# -------  Class: chair            AP:   0.4646  -------
# -------  Class: cow              AP:   0.2113  -------
# -------  Class: diningtable      AP:   0.3858  -------
# -------  Class: dog              AP:   0.3503  -------
# -------  Class: horse            AP:   0.5635  -------
# -------  Class: motorbike        AP:   0.6161  -------
# -------  Class: person           AP:   0.7732  -------
# -------  Class: pottedplant      AP:   0.2132  -------
# -------  Class: sheep            AP:   0.1454  -------
# -------  Class: sofa             AP:   0.3612  -------
# -------  Class: train            AP:   0.6898  -------
# -------  Class: tvmonitor        AP:   0.4300  -------
# mAP: 0.4428
# Avg loss: 0.16703875586390496
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 90 is 0.4428141820735788
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.12786582112312317
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.12688009440898895
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.12811988592147827
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.1281190663576126
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.12681293487548828
# -------  Class: aeroplane        AP:   0.6772  -------
# -------  Class: bicycle          AP:   0.4528  -------
# -------  Class: bird             AP:   0.3516  -------
# -------  Class: boat             AP:   0.5578  -------
# -------  Class: bottle           AP:   0.1915  -------
# -------  Class: bus              AP:   0.3448  -------
# -------  Class: car              AP:   0.6838  -------
# -------  Class: cat              AP:   0.3984  -------
# -------  Class: chair            AP:   0.4694  -------
# -------  Class: cow              AP:   0.2176  -------
# -------  Class: diningtable      AP:   0.3860  -------
# -------  Class: dog              AP:   0.3458  -------
# -------  Class: horse            AP:   0.5629  -------
# -------  Class: motorbike        AP:   0.6147  -------
# -------  Class: person           AP:   0.7725  -------
# -------  Class: pottedplant      AP:   0.2093  -------
# -------  Class: sheep            AP:   0.1517  -------
# -------  Class: sofa             AP:   0.3672  -------
# -------  Class: train            AP:   0.6874  -------
# -------  Class: tvmonitor        AP:   0.4368  -------
# mAP: 0.4440
# Avg loss: 0.16712091863155365
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 95 is 0.44395950318302335
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.1281009018421173
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.1274121254682541
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.1269141286611557
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.12764498591423035
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.12744350731372833
# -------  Class: aeroplane        AP:   0.6763  -------
# -------  Class: bicycle          AP:   0.4499  -------
# -------  Class: bird             AP:   0.3533  -------
# -------  Class: boat             AP:   0.5525  -------
# -------  Class: bottle           AP:   0.1915  -------
# -------  Class: bus              AP:   0.3393  -------
# -------  Class: car              AP:   0.6847  -------
# -------  Class: cat              AP:   0.3975  -------
# -------  Class: chair            AP:   0.4680  -------
# -------  Class: cow              AP:   0.2178  -------
# -------  Class: diningtable      AP:   0.3823  -------
# -------  Class: dog              AP:   0.3459  -------
# -------  Class: horse            AP:   0.5622  -------
# -------  Class: motorbike        AP:   0.6152  -------
# -------  Class: person           AP:   0.7720  -------
# -------  Class: pottedplant      AP:   0.2069  -------
# -------  Class: sheep            AP:   0.1470  -------
# -------  Class: sofa             AP:   0.3629  -------
# -------  Class: train            AP:   0.6900  -------
# -------  Class: tvmonitor        AP:   0.4338  -------
# mAP: 0.4425
# Avg loss: 0.16744709014892578
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.4424528721151531

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
ds_test = VocDataset('VOCdevkit_2007/VOC2007test/','test', test_transform)
test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=batch_size,
                                               shuffle=False,
                                               num_workers=1)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.6934  -------
# -------  Class: bicycle          AP:   0.4597  -------
# -------  Class: bird             AP:   0.3898  -------
# -------  Class: boat             AP:   0.4986  -------
# -------  Class: bottle           AP:   0.2067  -------
# -------  Class: bus              AP:   0.4131  -------
# -------  Class: car              AP:   0.6998  -------
# -------  Class: cat              AP:   0.3940  -------
# -------  Class: chair            AP:   0.4803  -------
# -------  Class: cow              AP:   0.2204  -------
# -------  Class: diningtable      AP:   0.4206  -------
# -------  Class: dog              AP:   0.3380  -------
# -------  Class: horse            AP:   0.7096  -------
# -------  Class: motorbike        AP:   0.6190  -------
# -------  Class: person           AP:   0.8022  -------
# -------  Class: pottedplant      AP:   0.2222  -------
# -------  Class: sheep            AP:   0.2561  -------
# -------  Class: sofa             AP:   0.3146  -------
# -------  Class: train            AP:   0.7002  -------
# -------  Class: tvmonitor        AP:   0.3531  -------
# mAP: 0.4596
# Avg loss: 0.15956911826745057
# 0.459567180662242

# %%
torch.save(classifier.state_dict(), './voc_my_best_classifier.pth')
output_submission_csv('my_solution.csv', test_aps)
